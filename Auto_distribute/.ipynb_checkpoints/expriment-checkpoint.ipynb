# %%
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # Importing Dataset

# %%
pd.read_csv('AEX D1 10Y.csv', usecols=['Date', 'Open', 'High', 'Low'], parse_dates=['Date'], index_col=['Date'])
# Out:
#               Open    High     Low
# Date
# 2020-07-24  568.08  568.14  560.54
# 2020-07-23  578.41  580.74  574.98
# 2020-07-22  578.40  579.21  571.35
# 2020-07-21  584.04  587.03  580.42
# 2020-07-20  573.48  580.46  569.46
# ...            ...     ...     ...
# 2010-07-02  310.38  312.64  308.18
# 2010-07-01  313.05  314.81  306.42
# 2010-06-30  319.85  320.31  315.81
# 2010-06-29  326.35  326.50  318.14
# 2010-06-28  327.33  331.04  325.39
#
# [2580 rows x 3 columns]

# %% [markdown]
# # formating data

# %%
price_data = pd.read_csv('AEX D1 10Y.csv', usecols=['Date', 'Open', 'High', 'Low'], parse_dates=['Date'], index_col=['Date'])
# price_data['Open'] = price_data['Open'].str.split(',').str.join('').astype('float')
# price_data['High'] = price_data['High'].str.split(',').str.join('').astype('float')
# price_data['Low'] = price_data['Low'].str.split(',').str.join('').astype('float')

# %%
price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2580 entries, 2020-07-24 to 2010-06-28
# Data columns (total 3 columns):
# Open    2580 non-null float64
# High    2580 non-null float64
# Low     2580 non-null float64
# dtypes: float64(3)
# memory usage: 80.6 KB

# %% [markdown]
# # Sorting in assending date order

# %%
price_data.sort_index(inplace=True)

# %% [markdown]
# # Open to Open % Change

# %%
price_data['O2O %'] = (price_data['Open'].pct_change() * 100).round(3)
price_data
# Out:
#                 Open      High       Low  O2O %
# Date
# 2010-06-23   8418.41   8514.21   8368.00    NaN
# 2010-06-24   8423.54   8437.69   8215.33  0.061
# 2010-06-25   8241.89   8278.21   8140.00 -2.156
# 2010-06-28   8190.88   8321.08   8145.19 -0.619
# 2010-06-29   8243.63   8243.63   7991.28  0.644
# ...              ...       ...       ...    ...
# 2020-07-17  27091.39  27110.64  26860.12  0.357
# 2020-07-20  26938.54  27177.22  26723.23 -0.564
# 2020-07-21  27317.69  27526.41  27211.61  1.407
# 2020-07-22  27184.35  27390.38  27080.35 -0.488
# 2020-07-23  27423.92  27436.50  27226.32  0.881
#
# [2556 rows x 4 columns]

# %% [markdown]
# # H 2 L % Change

# %%
price_data['H2L %'] = (((price_data['High'] - price_data['Low'])/price_data['Low']) * 100).round(3)
price_data
# Out:
#                 Open      High       Low  O2O %  H2L %
# Date
# 2010-06-23   8418.41   8514.21   8368.00    NaN  1.747
# 2010-06-24   8423.54   8437.69   8215.33  0.061  2.707
# 2010-06-25   8241.89   8278.21   8140.00 -2.156  1.698
# 2010-06-28   8190.88   8321.08   8145.19 -0.619  2.159
# 2010-06-29   8243.63   8243.63   7991.28  0.644  3.158
# ...              ...       ...       ...    ...    ...
# 2020-07-17  27091.39  27110.64  26860.12  0.357  0.933
# 2020-07-20  26938.54  27177.22  26723.23 -0.564  1.699
# 2020-07-21  27317.69  27526.41  27211.61  1.407  1.157
# 2020-07-22  27184.35  27390.38  27080.35 -0.488  1.145
# 2020-07-23  27423.92  27436.50  27226.32  0.881  0.772
#
# [2556 rows x 5 columns]

# %%
price_data['O2O %'].idxmax()
# Out:
# Timestamp('2020-03-20 00:00:00')

# %% [markdown]
# # Plotting histogram with bin size

# %%
price_data['O2O %'].hist(bins=22, figsize=(10, 6))

# %%
price_data['O2O %'].nlargest(10)
# Out:
# Date
# 2020-03-20    6.928
# 2020-03-25    6.297
# 2011-12-01    5.135
# 2011-08-10    5.088
# 2011-11-04    4.707
# 2011-09-15    4.400
# 2011-08-15    4.008
# 2011-11-14    3.774
# 2011-10-07    3.609
# 2020-03-27    3.573
# Name: O2O %, dtype: float64

# %%
price_data['O2O %'].nsmallest(10)
# Out:
# Date
# 2011-08-05   -9.378
# 2020-03-09   -7.635
# 2020-03-12   -6.125
# 2016-06-24   -5.835
# 2011-08-19   -5.799
# 2020-03-16   -5.679
# 2011-08-09   -5.401
# 2020-02-28   -5.175
# 2020-03-18   -5.085
# 2016-02-09   -4.830
# Name: O2O %, dtype: float64

# %% [markdown]
# # Creating Bin

# %%
max = int(price_data['O2O %'].max() + 0.5)
max
# Out:
# 7

# %%
min = int(price_data['O2O %'].min() - 1)
min
# Out:
# -10

# %%
k = int(abs((min - max)/0.5))
k
# Out:
# 34

# %%
bin = [min]
for i in range(k):
    min += 0.5
    bin.append(min)
bin_Series = pd.Series(bin).round(4)
bin_Series
# Out:
# 0    -10.0
# 1     -9.5
# 2     -9.0
# 3     -8.5
# 4     -8.0
# 5     -7.5
# 6     -7.0
# 7     -6.5
# 8     -6.0
# 9     -5.5
# 10    -5.0
# 11    -4.5
# 12    -4.0
# 13    -3.5
# 14    -3.0
# 15    -2.5
# 16    -2.0
# 17    -1.5
# 18    -1.0
# 19    -0.5
# 20     0.0
# 21     0.5
# 22     1.0
# 23     1.5
# 24     2.0
# 25     2.5
# 26     3.0
# 27     3.5
# 28     4.0
# 29     4.5
# 30     5.0
# 31     5.5
# 32     6.0
# 33     6.5
# 34     7.0
# dtype: float64

# %%
price_data['O2O %'].hist(bins=bin)
# Out:
# <img src="data:image/png;base64,..." width="813">

# %%
#_______________Calculating H2L Probability distribution___________________#

h2lmin = int(price_data['H2L %'].min())
h2lmin
h2lmax = int(price_data['H2L %'].max() + 2)
h2lmax
# Divisor
k2 = int(abs((h2lmin - h2lmax)/0.3))
k2
# creating bin series
bin2 = [h2lmin]
for i in range(k2):
    h2lmin += 0.3
    bin2.append(h2lmin)
h2l_bin_Series = pd.Series(bin2).round(3)

# %%
price_data['H2L %'].hist(bins=bin2, figsize=(10, 6))

# %%
fig, axis = plt.subplots(nrows=2, ncols=1, figsize=(14, 16))
price_data['H2L %'].hist(bins=bin2, ax=axis[1])
price_data['O2O %'].hist(bins=bin , ax=axis[0])
fig.subplots_adjust(hspace=0.3)

axis[0].set_title('Open to Open Returns Distribution', fontsize=16)
axis[0].set_xlabel('Returns', fontsize=14)
axis[0].set_ylabel('Frequency', fontsize=14)
axis[1].set_title('High to Low Returns Distribution', fontsize=16)
axis[1].set_xlabel('Returns', fontsize=14)
axis[1].set_ylabel('Frequency', fontsize=14)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Calculating Frequency for probability calculation

# %%
def occurence(array):
    start = array[0]
    end = array[1]
    
    k = price_data[price_data['O2O %'].between(start, end)]
    return k['O2O %'].count()

# %%
occurrences = bin_Series.rolling(2).apply(occurence, raw=True)

# %%
occ_df = pd.concat([bin_Series, occurrences], axis=1)
occ_df.columns = ['Percent', 'Frequency']
occ_df
# Out:
#     Percent  Frequency
# 0     -10.0        NaN
# 1      -9.5        0.0
# 2      -9.0        1.0
# 3      -8.5        0.0
# 4      -8.0        0.0
# 5      -7.5        1.0
# 6      -7.0        0.0
# 7      -6.5        0.0
# 8      -6.0        1.0
# 9      -5.5        3.0
# 10     -5.0        3.0
# 11     -4.5        3.0
# 12     -4.0        4.0
# 13     -3.5        8.0
# 14     -3.0       13.0
# 15     -2.5       19.0
# 16     -2.0       35.0
# 17     -1.5       80.0
# 18     -1.0      150.0
# 19     -0.5      303.0
# 20      0.0      535.0
# 21      0.5      610.0
# 22      1.0      423.0
# 23      1.5      192.0
# 24      2.0       89.0
# 25      2.5       39.0
# 26      3.0       20.0
# 27      3.5       16.0
# 28      4.0        3.0
# 29      4.5        2.0
# 30      5.0        1.0
# 31      5.5        2.0
# 32      6.0        0.0
# 33      6.5        1.0
# 34      7.0        1.0
# 35      7.5        0.0

# %% [markdown]
# # Probability of each occurance

# %%
(occ_df['Frequency']/len(price_data['O2O %']) * 100).round(2)
# Out:
# 0       NaN
# 1      0.00
# 2      0.04
# 3      0.00
# 4      0.00
# 5      0.04
# 6      0.00
# 7      0.00
# 8      0.04
# 9      0.12
# 10     0.12
# 11     0.12
# 12     0.16
# 13     0.31
# 14     0.51
# 15     0.74
# 16     1.37
# 17     3.13
# 18     5.87
# 19    11.85
# 20    20.93
# 21    23.87
# 22    16.55
# 23     7.51
# 24     3.48
# 25     1.53
# 26     0.78
# 27     0.63
# 28     0.12
# 29     0.08
# 30     0.04
# 31     0.08
# 32     0.00
# 33     0.04
# 34     0.04
# 35     0.00
# Name: Frequency, dtype: float64

# %% [markdown]
# # Cumulative probability

# %%
((occ_df['Frequency']/price_data['O2O %'].count() * 100).round(2)).expanding(1).sum()
# Out:
# 0        NaN
# 1       0.00
# 2       0.04
# 3       0.04
# 4       0.04
# 5       0.08
# 6       0.08
# 7       0.08
# 8       0.12
# 9       0.24
# 10      0.36
# 11      0.48
# 12      0.64
# 13      0.95
# 14      1.46
# 15      2.20
# 16      3.57
# 17      6.70
# 18     12.57
# 19     24.43
# 20     45.37
# 21     69.24
# 22     85.80
# 23     93.31
# 24     96.79
# 25     98.32
# 26     99.10
# 27     99.73
# 28     99.85
# 29     99.93
# 30     99.97
# 31    100.05
# 32    100.05
# 33    100.09
# 34    100.13
# 35    100.13
# Name: Frequency, dtype: float64

# %%
prob = (occ_df['Frequency']/len(price_data['O2O %']) * 100).round(2)
cu_prob = ((occ_df['Frequency']/price_data['O2O %'].count() * 100).round(2)).expanding(1).sum()

prob_df = pd.concat([prob, cu_prob], axis=1)
prob_df.columns = ['Probability', 'Cum Frequency']
prob_df
# Out:
#     Probability  Cum Frequency
# 0           NaN            NaN
# 1          0.00           0.00
# 2          0.04           0.04
# 3          0.00           0.04
# 4          0.00           0.04
# 5          0.04           0.08
# 6          0.00           0.08
# 7          0.00           0.08
# 8          0.04           0.12
# 9          0.12           0.24
# 10         0.12           0.36
# 11         0.12           0.48
# 12         0.16           0.64
# 13         0.31           0.95
# 14         0.51           1.46
# 15         0.74           2.20
# 16         1.37           3.57
# 17         3.13           6.70
# 18         5.87          12.57
# 19        11.85          24.43
# 20        20.93          45.37
# 21        23.87          69.24
# 22        16.55          85.80
# 23         7.51          93.31
# 24         3.48          96.79
# 25         1.53          98.32
# 26         0.78          99.10
# 27         0.63          99.73
# 28         0.12          99.85
# 29         0.08          99.93
# 30         0.04          99.97
# 31         0.08         100.05
# 32         0.00         100.05
# 33         0.04         100.09
# 34         0.04         100.13
# 35         0.00         100.13

# %%
probability_main = pd.concat([occ_df, prob_df], axis=1)
probability_main
# Out:
#     Percent  Frequency  Probability  Cum Frequency
# 0     -10.0        NaN          NaN            NaN
# 1      -9.5        0.0         0.00           0.00
# 2      -9.0        1.0         0.04           0.04
# 3      -8.5        0.0         0.00           0.04
# 4      -8.0        0.0         0.00           0.04
# 5      -7.5        1.0         0.04           0.08
# 6      -7.0        0.0         0.00           0.08
# 7      -6.5        0.0         0.00           0.08
# 8      -6.0        1.0         0.04           0.12
# 9      -5.5        3.0         0.12           0.24
# 10     -5.0        3.0         0.12           0.36
# 11     -4.5        3.0         0.12           0.48
# 12     -4.0        4.0         0.16           0.64
# 13     -3.5        8.0         0.31           0.95
# 14     -3.0       13.0         0.51           1.46
# 15     -2.5       19.0         0.74           2.20
# 16     -2.0       35.0         1.37           3.57
# 17     -1.5       80.0         3.13           6.70
# 18     -1.0      150.0         5.87          12.57
# 19     -0.5      303.0        11.85          24.43
# 20      0.0      535.0        20.93          45.37
# 21      0.5      610.0        23.87          69.24
# 22      1.0      423.0        16.55          85.80
# 23      1.5      192.0         7.51          93.31
# 24      2.0       89.0         3.48          96.79
# 25      2.5       39.0         1.53          98.32
# 26      3.0       20.0         0.78          99.10
# 27      3.5       16.0         0.63          99.73
# 28      4.0        3.0         0.12          99.85
# 29      4.5        2.0         0.08          99.93
# 30      5.0        1.0         0.04          99.97
# 31      5.5        2.0         0.08         100.05
# 32      6.0        0.0         0.00         100.05
# 33      6.5        1.0         0.04         100.09
# 34      7.0        1.0         0.04         100.13
# 35      7.5        0.0         0.00         100.13

# %% [markdown]
# # adding to decription

# %%
def descriptor(df, col_name):
    description = df[col_name].describe().to_dict()
    description['kertosis'] = df[col_name].kurtosis()
    description['skew'] = df[col_name].skew()
    description['median'] = df[col_name].median()
    description['Sample Variance'] = df[col_name].var()
    
    return pd.Series(description)

# %%
descriptor(price_data, 'O2O %')
# Out:
# count              2555.000000
# mean                  0.052729
# std                   1.137590
# min                  -9.378000
# 25%                  -0.470500
# 50%                   0.094000
# 75%                   0.620000
# max                   6.928000
# kertosis              6.282718
# skew                 -0.636738
# median                0.094000
# Sample Variance       1.294110
# dtype: float64

# %%
descriptor(price_data, 'H2L %')
# Out:
# count              2556.000000
# mean                  1.295719
# std                   0.893704
# min                   0.000000
# 25%                   0.743000
# 50%                   1.063000
# 75%                   1.586500
# max                   9.729000
# kertosis             17.946805
# skew                  3.214584
# median                1.063000
# Sample Variance       0.798707
# dtype: float64

# %% [markdown]
# # Averages

# %%
# Open 2 Open mean

avgO2O = price_data['O2O %'].mean()
avgO2O
# Out:
# 0.05272876712328758

# %%
# Open 2 Open Count

price_data['O2O %'].count()
# Out:
# 2555

# %%
# positive & negative boolean Series

positive_mask = price_data['O2O %'] > 0
negative_mask = price_data['O2O %'] < 0

# %%
# Average positive return

pos_ret = price_data[positive_mask]['O2O %'].mean()
# Out:
# 0.7736387696709593

# %%
# Average negative return

neg_ret = price_data[negative_mask]['O2O %'].mean()
# Out:
# -0.8183448573898012

# %%
# positive count(days)

pos_count = price_data[positive_mask]['O2O %'].count()
# Out:
# 1398

# %%
# negative count(days)

neg_count = price_data[negative_mask]['O2O %'].count()
# Out:
# 1157

# %%
pos_ret = price_data[positive_mask]['O2O %'].mean()
neg_ret = price_data[negative_mask]['O2O %'].mean()
pos_count = price_data[positive_mask]['O2O %'].count()
neg_count = price_data[negative_mask]['O2O %'].count()

avg_df = pd.DataFrame([(pos_ret, pos_count), (neg_ret, neg_count)], columns=['Return', 'Count'])
avg_df.index = ['Pos', 'Neg']
avg_df['Count%'] = avg_df['Count'] / len(price_data) * 100
avg_df['Adjusted ret'] = avg_df['Return'] * avg_df['Count%']
avg_df
# Out:
#        Return  Count     Count%  Adjusted ret
# Pos  0.773639   1398  54.694836     42.314045
# Neg -0.818345   1157  45.266041    -37.043232

# %% [markdown]
# # Std dev

# %%
upper = dict()
lower = dict()
for i in range(1, 4):
    upper[i] = (i*price_data['O2O %'].std())+avgO2O
    lower[i] = avgO2O - (i*price_data['O2O %'].std())

up_std = pd.Series(upper)
low_std = pd.Series(lower)

# %%
std_dev = pd.concat([up_std, low_std], axis=1)
std_dev.columns = ['upper', 'lower']

# %%
std_dev
# Out:
#       upper     lower
# 1  1.190318 -1.084861
# 2  2.327908 -2.222451
# 3  3.465498 -3.360040

# %%
std_dev.iloc[0, 0]
# Out:
# 1.1903184615459066

# %%
price_data[price_data['O2O %'].between(std_dev.iloc[0, 1], std_dev.iloc[0, 0])]
# Out:
# Date
# 2010-06-23    False
# 2010-06-24     True
# 2010-06-25    False
# 2010-06-28     True
# 2010-06-29     True
#               ...
# 2020-07-17     True
# 2020-07-20     True
# 2020-07-21    False
# 2020-07-22     True
# 2020-07-23     True
# Name: O2O %, Length: 2556, dtype: bool

# %%
# occurance between 1 upper & lower std-dev

len(price_data[price_data['O2O %'].between(std_dev.iloc[0, 1], std_dev.iloc[0, 0])])
# Out:
# 1991

# %%
# occurance between 2 upper & lower std-dev

len(price_data[price_data['O2O %'].between(std_dev.iloc[1, 1], std_dev.iloc[1, 0])])
# Out:
# 2427

# %%
# occurance beween 3 upper & lower std-dev

len(price_data[price_data['O2O %'].between(std_dev.iloc[2, 1], std_dev.iloc[2, 0])])
# Out:
# 2514

# %%
std_1 = len(price_data[price_data['O2O %'].between(std_dev.iloc[0, 1], std_dev.iloc[0, 0])])
std_2 = len(price_data[price_data['O2O %'].between(std_dev.iloc[1, 1], std_dev.iloc[1, 0])])
std_3 = len(price_data[price_data['O2O %'].between(std_dev.iloc[2, 1], std_dev.iloc[2, 0])])

# %%
std_1 / len(price_data) * 100
# Out:
# 77.89514866979655

# %%
std_2 / len(price_data) * 100
# Out:
# 94.95305164319248

# %%
std_3/ len(price_data) * 100
# Out:
# 98.35680751173709

# %%
t1 = (std_1, std_1 / len(price_data) * 100)
t2 = (std_2, std_2 / len(price_data) * 100)
t3 = (std_3, std_3 / len(price_data) * 100)

df = pd.DataFrame([t1, t2, t3], columns=['count', 'percentage'])
df.index = [1, 2, 3]
df
# Out:
#    count  percentage
# 1   1991   77.895149
# 2   2427   94.953052
# 3   2514   98.356808

# %%
df.index.name = 'Std_dev'

# %%
pd.concat([std_dev, df], axis=1)
# Out:
#       upper     lower  count  percentage
# 1  1.190318 -1.084861   1991   77.895149
# 2  2.327908 -2.222451   2427   94.953052
# 3  3.465498 -3.360040   2514   98.356808

# %%
h2lmin = int(price_data['H2L %'].min())
h2lmax = int(price_data['H2L %'].max() + 1)

# Divisor
k2 = int(abs((h2lmax - h2lmin)/0.5))

# creating bin series
bin2 = [h2lmin]
for i in range(k2):
    h2lmin += 0.5
    bin2.append(h2lmin)
h2l_bin_Series = pd.Series(bin2).round(3)


def frequency2(array):
    start = array[0]
    end = array[1]
    
    k = price_data[price_data['H2L %'].between(start, end)]
    return k['H2L %'].count()

h2l_frequency_series = h2l_bin_Series.rolling(2).apply(frequency2, raw=True)

h2l_frequency_table = pd.concat([h2l_bin_Series, h2l_frequency_series], axis=1)         # Frequency Table
h2l_frequency_table.columns = ['bin', 'Frequency']
h2l_frequency_table.fillna(value=0, inplace=True)

# Probability & Cu-probability
h2l_prob_Series = (h2l_frequency_table['Frequency']/len(price_data['H2L %']) * 100).round(2)
h2l_cumprob = ((h2l_frequency_table['Frequency']/len(price_data['H2L %']) * 100).round(2)).cumsum()

h2l_prob_table = pd.concat([h2l_prob_Series, h2l_cumprob], axis=1)               # Probability table
h2l_prob_table.columns = ['Probability %', 'Cum Probability %']

h2l_probability_distribution = pd.concat([h2l_frequency_table, h2l_prob_table], axis=1)      # probability distribution
# Out:
#      bin  Frequency  Probability %  Cum Probability %
# 0    0.0        0.0           0.00               0.00
# 1    0.5      163.0           6.38               6.38
# 2    1.0     1001.0          39.16              45.54
# 3    1.5      678.0          26.53              72.07
# 4    2.0      344.0          13.46              85.53
# 5    2.5      191.0           7.47              93.00
# 6    3.0       78.0           3.05              96.05
# 7    3.5       37.0           1.45              97.50
# 8    4.0       26.0           1.02              98.52
# 9    4.5       12.0           0.47              98.99
# 10   5.0        5.0           0.20              99.19
# 11   5.5        6.0           0.23              99.42
# 12   6.0        5.0           0.20              99.62
# 13   6.5        2.0           0.08              99.70
# 14   7.0        1.0           0.04              99.74
# 15   7.5        1.0           0.04              99.78
# 16   8.0        1.0           0.04              99.82
# 17   8.5        5.0           0.20             100.02
# 18   9.0        0.0           0.00             100.02
# 19   9.5        1.0           0.04             100.06
# 20  10.0        1.0           0.04             100.10
